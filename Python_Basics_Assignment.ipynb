# %% [markdown]
# #Python Basics
#
# Q1- What is Python, and why is it popular?
# Ans - Python is an open-source programming language that is free to use and distribute.Python is widely used in web development, data science, machine learning, and automation.
# Phython is Popular because:Python is easy to learn, Python has an active, supportive community, Python is flexible,Python offers versatile web-development solutions , Python is well suited to data science and analytics, Python is efficient, fast, and reliable7. Python is widely used with IoT Technology
#
# Q2- What is an interpreter in Python?
# Ans - An interpreter in Python is a program that reads and executes Python code line by line, translating it into machine-readable instructions and then running them.
#
# Q3- What are pre-defined keywords in Python?
# Ans - Predefined keywords are reserved words with special meanings so the interpreter can understand them.
#
# Q4- Can keywords be used as variable names?
# Ans- No
#
# Q5- What is mutability in Python?
# Ans- Mutability refers to an object's ability to be changed after it's created.
# eg - lists and dictionaries
#
# Q6- Why are lists mutable, but tuples are immutable?
# Ans- Tuples and lists are the same in every way except two: tuples use parentheses instead of square brackets, and the items in tuples cannot be modified (but the items in lists can be modified). We often call lists mutable (meaning they can be changed) and tuples immutable (meaning they cannot be changed).
#
# Q7- What is the difference between “==” and “is” operators in Python?
# Ans- The '==' is known as the equality operator.In Python, == checks for value equality (whether two objects have the same value), while is checks for object identity (whether two variables point to the same object in memory).
# Example:
# a = 5
# b = 5
# c = [1, 2, 3]
# d = [1, 2, 3]
#
# print(a == b)  # True (values are equal)
# print(a is b)  # True (both variables point to the same object, in this case a small integer)
#
# print(c == d)  # True (values are equal)
# print(c is d)  # False (variables point to different objects in memory)
#
# Q8- What are logical operators in Python?
# Ans- Python logical operators are used to combine conditional statements, allowingto perform operations based on multiple conditions. These Python operators, alongside arithmetic operators, are special symbols used to carry out computations on values and variables.
# Eg: AND, OR, NOT
#
# Q9- What is type casting in Python?
# Ans- In Python, type casting (also known as type conversion) is the process of converting a variable's data type to another, either implicitly (automatically by Python) or explicitly (using built-in functions like int(), float(), str(), etc.).
#
# Q10- What is the difference between implicit and explicit type casting?
# Ans- Implicit type casting is automatic, while explicit type casting is done by the programmer.
#
# Q11- What is the purpose of conditional statements in Python?
# Ans- Conditional statements in Python, like if, elif, and else, allow your code to make decisions and execute different blocks of code based on whether a condition is true or false,
#
# Q12- How does the elif statement work?
# Ans- The “elif” keyword in Python, stands for “else if”. It can be used in conditional statements to check for multiple conditions. For example, if the first condition is false, it moves on to the next “elif” statement to check if that condition is true.
#
# Q13- what is the difference between for loop and while loops?
# Ans- A for loop in Python repeats executing a code block from a sequence till certain number of times. Whereas a while loop in Python repeats execution of a code block till the condition is true which is not certain.
#
# Q14- Describe a scenario where a while loop is more suitable than a for loop?
# Ans- A while loop is more suitable than a for loop when you need to repeat an action until a certain condition is met, but you don't know in advance how many times the loop will run. This contrasts with a for loop, which is better suited for situations where the number of iterations is known beforehand.
#
# Example: Asking for a valid number
# # Repeatedly ask the user for input until they enter a valid number
# while True:
#     user_input = input("Please enter a number: ")
#
#     if user_input.isdigit():
#         print(f"Thank you! You entered the number: {user_input}")
#         break  # Exit the loop if a valid number is entered
#     else:
#         print("That's not a valid number. Please try again.")

# %%
#Q1 Write a Python program to print "Hello, World!_
print("Hello, World!")


#Q2 Write a Python program that displays your name and age
name = "Ravi"
age = 26
print(f"My name is {name} and I am {age} years old.")

#Q3 Write code to print all the pre-defined keywords in Python using the keyword library
import keyword
print(keyword.kwlist)

#Q4 Write a program that checks if a given word is a Python keyword
import keyword
word = input("Enter a word to check if it's a Python keyword: ")
if keyword.iskeyword(word):
    print(f"'{word}' is a Python keyword.")
else:
    print(f"'{word}' is not a Python keyword.")

#Q5Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each
my_list = [1, 2, 3, 4, 5]
my_tuple = (1, 2, 3, 4, 5)

print("Original list:", my_list)
my_list[2] = 10
print("Modified list:", my_list)


print("\nOriginal tuple:", my_tuple)
try:
    my_tuple[2] = 10
except TypeError as e:
    print("Error:", e)


#Q6 Write a function to demonstrate the behavior of mutable and immutable arguments
def modify_arguments(mutable_arg, immutable_arg):
    mutable_arg.append(100)
    print("Inside function - mutable_arg:", mutable_arg)

    immutable_arg += 10
    print("Inside function - immutable_arg:", immutable_arg)

my_list = [1, 2, 3]
my_number = 5

print("Before calling function:")
print("my_list:", my_list)
print("my_number:", my_number)

modify_arguments(my_list, my_number)

print("\nAfter calling function:")
print("my_list:", my_list)
print("my_number:", my_number)

#Q8 Write a program to demonstrate the use of logical operators
def logical_operators_demo(a, b):
    if a > 0 and b > 0:
        print("Both a and b are positive.")
    else:
        print("At least one of a or b is not positive.")

    if a > 0 or b > 0:
        print("At least one of a or b is positive.")
    else:
        print("Neither a nor b is positive.")

    if not (a > 0):
        print("a is not positive.")
    if not (b > 0):
        print("b is not positive.")

a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))

logical_operators_demo(a, b)


#Q9 Write a Python program to convert user input from string to integer, float, and boolean types
def convert_input():

    user_input = input("Enter a value: ")

    try:
        int_value = int(user_input)
        print(f"Integer value: {int_value}")
    except ValueError:
     print("Cannot convert to integer.")

    try:
        float_value = float(user_input)
        print(f"Float value: {float_value}")
    except ValueError:
        print("Cannot convert to float.")

    if user_input.lower() in ['true', '1', 'yes', 'y']:
        bool_value = True
    else:
        bool_value = False
    print(f"Boolean value: {bool_value}")

convert_input()


#Q10 Write code to demonstrate type casting with list elements
def demonstrate_type_casting():

    string_list = ["10", "20.5", "True", "50", "False"]

    print("Original List:")
    print(string_list)

    int_list = [int(x) if x.isdigit() else x for x in string_list]
    print("\nList with elements converted to integers (if possible):")
    print(int_list)

    float_list = [float(x) if x.replace('.', '', 1).isdigit() else x for x in string_list]
    print("\nList with elements converted to floats (if possible):")
    print(float_list)

    bool_list = [x.lower() in ['true', '1', 'yes'] for x in string_list]
    print("\nList with elements converted to booleans:")
    print(bool_list)

    str_list = [str(x) for x in int_list]
    print("\nList with elements converted to strings:")
    print(str_list)

demonstrate_type_casting()


#Q11 Write a program that checks if a number is positive, negative, or zero
def check_number():

    number = float(input("Enter a number: "))

    if number > 0:
        print("The number is positive.")
    elif number < 0:
        print("The number is negative.")
    else:
        print("The number is zero.")

check_number()

#Q12 Write a for loop to print numbers from 1 to 10
for i in range(1, 11):
    print(i)


#Q13 Write a Python program to find the sum of all even numbers between 1 and 50
sum_even = 0

for number in range(1, 51):

    if number % 2 == 0:
        sum_even += number

print("Sum of all even numbers between 1 and 50:", sum_even)


#Q14 Write a program to reverse a string using a while loop
def reverse_string(input_string):

    reversed_string = ""


    index = len(input_string) - 1

    while index >= 0:

        reversed_string += input_string[index]

        index -= 1

    return reversed_string

user_input = input("Enter a string: ")

print("Reversed string:", reverse_string(user_input))


#Q15 Write a Python program to calculate the factorial of a number provided by the user using a while loop.
def calculate_factorial(n):

    factorial = 1

    if n < 0:
        return "Factorial is not defined for negative numbers."

    while n > 1:
        factorial *= n
        n -= 1

    return factorial

num = int(input("Enter a number to calculate its factorial: "))

print(f"The factorial is: {calculate_factorial(num)}")
# Out:
# Hello, World!
# My name is Ravi and I am 26 years old.
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Enter a word to check if it's a Python keyword: tyt
# 'tyt' is not a Python keyword.
# Original list: [1, 2, 3, 4, 5]
# Modified list: [1, 2, 10, 4, 5]
#
# Original tuple: (1, 2, 3, 4, 5)
# Error: 'tuple' object does not support item assignment
# Before calling function:
# my_list: [1, 2, 3]
# my_number: 5
# Inside function - mutable_arg: [1, 2, 3, 100]
# Inside function - immutable_arg: 15
#
# After calling function:
# my_list: [1, 2, 3, 100]
# my_number: 5
# Enter the value of a: 7
# Enter the value of b: 0
# At least one of a or b is not positive.
# At least one of a or b is positive.
# b is not positive.
# Enter a value: 12
# ...
